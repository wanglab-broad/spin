# %%
from glob import glob
import os
import matplotlib.pyplot as plt
import numpy as np
import matplotlib as mpl
import scanpy as sc
import numpy as np
from sklearn.neighbors import NearestNeighbors
from sklearn.decomposition import PCA
import scipy as sp
from sklearn.cluster import KMeans
import matplotlib as mpl

# %%
figpath = '/stanley/WangLab/kamal/figures/projects/spin/reviews/brain/utag/'
os.makedirs(figpath, exist_ok=True)
dpi = 300

# %%
basepath = '/stanley/WangLab/kamal/data/projects/spin/reviews/results/brain/utag/'
n_sample_rates = 11
single_cell_results = '/stanley/WangLab/kamal/data/projects/spin/reviews/results/brain/knn/reconstructions_0.0_50physical_15latent'

# %%
radius = 550
k_physical = 50 # approximately; utag used
k_latent = 15

# %% [markdown]
# # Load results

# %%
param_sets = glob(os.path.join(basepath, f'*{radius}radius_{k_latent}latent*'))
param_sets.sort()
param_sets[0] = single_cell_results
n_params = len(param_sets)
recons = np.zeros((n_params,n_sample_rates))
kmeans_ari = np.zeros((n_params,n_sample_rates))
leiden_ari = np.zeros((n_params,n_sample_rates))

for i in range(n_params):
    outputs = glob(os.path.join(basepath,param_sets[i])+'/*.txt')

    for j in range(len(outputs)):
        split = outputs[j].split('.txt')[0].split('/')[-1].split('_')
        recons[i,j] = float(split[1])
        kmeans_ari[i,j] = float(split[2])
        leiden_ari[i,j] = float(split[3])

# %%
param_sets
# Out:
# ['/stanley/WangLab/kamal/data/projects/spin/reviews/results/brain/knn/reconstructions_0.0_50physical_15latent',
#  '/stanley/WangLab/kamal/data/projects/spin/reviews/results/brain/utag/reconstructions_0.1_550radius_15latent',
#  '/stanley/WangLab/kamal/data/projects/spin/reviews/results/brain/utag/reconstructions_0.2_550radius_15latent',
#  '/stanley/WangLab/kamal/data/projects/spin/reviews/results/brain/utag/reconstructions_0.3_550radius_15latent',
#  '/stanley/WangLab/kamal/data/projects/spin/reviews/results/brain/utag/reconstructions_0.4_550radius_15latent',
#  '/stanley/WangLab/kamal/data/projects/spin/reviews/results/brain/utag/reconstructions_0.5_550radius_15latent',
#  '/stanley/WangLab/kamal/data/projects/spin/reviews/results/brain/utag/reconstructions_0.6_550radius_15latent',
#  '/stanley/WangLab/kamal/data/projects/spin/reviews/results/brain/utag/reconstructions_0.7_550radius_15latent',
#  '/stanley/WangLab/kamal/data/projects/spin/reviews/results/brain/utag/reconstructions_0.8_550radius_15latent',
#  '/stanley/WangLab/kamal/data/projects/spin/reviews/results/brain/utag/reconstructions_0.9_550radius_15latent',
#  '/stanley/WangLab/kamal/data/projects/spin/reviews/results/brain/utag/reconstructions_1.0_550radius_15latent',
#  '/stanley/WangLab/kamal/data/projects/spin/reviews/results/brain/utag/reconstructions_1_550radius_15latent']

# %%
recons = np.ma.masked_equal(recons,0)
kmeans_ari = np.ma.masked_equal(kmeans_ari,0)
leiden_ari = np.ma.masked_equal(leiden_ari,0)

# %%
# Multiply by ratio of n_nbrs to normalize to [0,1]
recons *= k_physical/k_latent

# %%
x = np.arange(n_params) * 10
plt.figure(figsize=(2.5,2))

# K-means
std = recons.std(axis=1)
mean = recons.mean(axis=1)
plt.plot(x, mean, color='k')
plt.fill_between(x, mean-std, mean+std, color='k', alpha=0.2)

plt.ylabel('Reconstruction')
plt.xlabel('Subsampling (% of neighbors)')
plt.gca().spines[['top','right']].set_visible(False)
tick_coords = np.arange(0,101,50)
tick_labels = tick_coords
plt.xticks(tick_coords, tick_labels)
# plt.xticks(x,x)
plt.grid()

filename = 'recon_curve.png'
filepath = os.path.join(figpath,filename)
plt.savefig(filepath, bbox_inches='tight', dpi=dpi)
plt.show()

# %%
x = np.arange(n_params) * 10
plt.figure(figsize=(2.5,2))

# K-means
std = kmeans_ari.std(axis=1)
mean = kmeans_ari.mean(axis=1)
plt.plot(x, mean, color='k', label='K-means')
plt.fill_between(x, mean-std, mean+std, color='k', alpha=0.2)

# Leiden
std = leiden_ari.std(axis=1)
mean = leiden_ari.mean(axis=1)
plt.plot(x, mean, color='k', label='Leiden', linestyle="--")
plt.fill_between(x, mean-std, mean+std, color='k', alpha=0.2)

plt.ylabel('ARI')
plt.xlabel('Subsampling (% of neighbors)')
# plt.legend(bbox_to_anchor=(-0.14,1.1))
plt.gca().spines[['top','right']].set_visible(False)
tick_coords = np.arange(0,101,50)
tick_labels = tick_coords
plt.xticks(tick_coords, tick_labels)
# plt.xticks(x,x)
plt.grid()

filename = 'ari_vs_subsampling.png'
filepath = os.path.join(figpath,filename)
plt.savefig(filepath, bbox_inches='tight', dpi=dpi)
plt.show()

# %%
# for i in range(n_sample_rates):

#     try:
#         path = glob(f'{param_sets[i]}/*.h5ad')[0]
    #     print('='*20)
    #     print(path)
    #     adata = sc.read_h5ad(path)

    #     sc.set_figure_params(figsize=(5,5))
    #     sc.pl.embedding(adata, basis='spatial', color='region_true', s=20, palette=sc.pl.palettes.default_102)
    #     sc.pl.embedding(adata, basis='spatial', color='leiden', s=20, palette=sc.pl.palettes.default_102)

    # except:
    #     print(f'No AnnData saved for {param_sets[i]}')

# %%
good_sample_rates = [1.0, 0.1]

for sample_rate in good_sample_rates:
    
    path = f'/stanley/WangLab/kamal/data/projects/spin/reviews/results/brain/utag/reconstructions_{sample_rate}_{radius}radius_{k_latent}latent/adata_{sample_rate}.h5ad'
    adata = sc.read_h5ad(path)

    sc.set_figure_params(figsize=(5,5))
    sc.pl.embedding(adata, basis='spatial', color='leiden', s=20, frameon=False, legend_loc=False, title='',
    return_fig=True, palette=sc.pl.palettes.default_102)

    filename = f'leiden_{sample_rate}.png'
    filepath = os.path.join(figpath,filename)
    plt.savefig(filepath, bbox_inches='tight', dpi=dpi)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[13], line 6
#       3 for sample_rate in good_sample_rates:
#       5     path = f'/stanley/WangLab/kamal/data/projects/spin/reviews/results/brain/utag/reconstructions_{sample_rate}_{radius}radius_{k_latent}latent/adata_{sample_rate}.h5ad'
# ----> 6     adata = sc.read_h5ad(path)
#       8     sc.set_figure_params(figsize=(5,5))
#       9     sc.pl.embedding(adata, basis='spatial', color='leiden', s=20, frameon=False, legend_loc=False, title='',
#      10     return_fig=True, palette=sc.pl.palettes.default_102)
#
# File /stanley/WangLab/kamal/envs/xax/lib/python3.9/site-packages/anndata/_io/h5ad.py:219, in read_h5ad(filename, backed, as_sparse, as_sparse_fmt, chunk_size)
#     211         raise NotImplementedError(
#     212             "Currently only `X` and `raw/X` can be read as sparse."
#     213         )
#     215 rdasp = partial(
#     216     read_dense_as_sparse, sparse_format=as_sparse_fmt, axis_chunk=chunk_size
#     217 )
# --> 219 with h5py.File(filename, "r") as f:
#     221     def callback(func, elem_name: str, elem, iospec):
#     222         if iospec.encoding_type == "anndata" or elem_name.endswith("/"):
#
# File /stanley/WangLab/kamal/envs/xax/lib/python3.9/site-packages/h5py/_hl/files.py:567, in File.__init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, fs_strategy, fs_persist, fs_threshold, fs_page_size, page_buf_size, min_meta_keep, min_raw_keep, locking, alignment_threshold, alignment_interval, meta_block_size, **kwds)
#     558     fapl = make_fapl(driver, libver, rdcc_nslots, rdcc_nbytes, rdcc_w0,
#     559                      locking, page_buf_size, min_meta_keep, min_raw_keep,
#     560                      alignment_threshold=alignment_threshold,
#     561                      alignment_interval=alignment_interval,
#     562                      meta_block_size=meta_block_size,
#     563                      **kwds)
#     564     fcpl = make_fcpl(track_order=track_order, fs_strategy=fs_strategy,
#     565                      fs_persist=fs_persist, fs_threshold=fs_threshold,
#     566                      fs_page_size=fs_page_size)
# --> 567     fid = make_fid(name, mode, userblock_size, fapl, fcpl, swmr=swmr)
#     569 if isinstance(libver, tuple):
#     570     self._libver = libver
#
# File /stanley/WangLab/kamal/envs/xax/lib/python3.9/site-packages/h5py/_hl/files.py:231, in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     229     if swmr and swmr_support:
#     230         flags |= h5f.ACC_SWMR_READ
# --> 231     fid = h5f.open(name, flags, fapl=fapl)
#     232 elif mode == 'r+':
#     233     fid = h5f.open(name, h5f.ACC_RDWR, fapl=fapl)
#
# File h5py/_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File h5py/h5f.pyx:106, in h5py.h5f.open()
#
# FileNotFoundError: [Errno 2] Unable to open file (unable to open file: name = '/stanley/WangLab/kamal/data/projects/spin/reviews/results/brain/utag/reconstructions_1.0_550radius_15latent/adata_1.0.h5ad', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)

# %% [markdown]
# # UMAP

# %%
good_sample_rates = [0.9, 0.1]

for sample_rate in good_sample_rates:
    
    path = f'/stanley/WangLab/kamal/data/projects/spin/reviews/results/brain/utag/reconstructions_{sample_rate}_{radius}radius_{k_latent}latent/adata_{sample_rate}.h5ad'
    adata = sc.read_h5ad(path)

    sc.tl.umap(adata, neighbors_key='smoothed')

    sc.set_figure_params(figsize=(5,5))
    sc.pl.embedding(adata, basis='X_umap', color='leiden', s=20, frameon=False, legend_loc=False, title='',
    return_fig=True, palette=sc.pl.palettes.default_102)

    filename = f'umap_{sample_rate}.png'
    filepath = os.path.join(figpath,filename)
    plt.savefig(filepath, bbox_inches='tight', dpi=dpi)

    adata.write(path[:-5]+'_umap.h5ad')
# Out:
# /stanley/WangLab/kamal/envs/xax/lib/python3.9/site-packages/umap/distances.py:1063: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# /stanley/WangLab/kamal/envs/xax/lib/python3.9/site-packages/umap/distances.py:1071: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# /stanley/WangLab/kamal/envs/xax/lib/python3.9/site-packages/umap/distances.py:1086: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# /stanley/WangLab/kamal/envs/xax/lib/python3.9/site-packages/umap/umap_.py:660: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# /stanley/WangLab/kamal/envs/xax/lib/python3.9/site-packages/umap/spectral.py:324: RuntimeWarning: divide by zero encountered in divide
#   1.0 / np.sqrt(diag_data), 0, graph.shape[0], graph.shape[0]
# /stanley/WangLab/kamal/envs/xax/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# /stanley/WangLab/kamal/envs/xax/lib/python3.9/site-packages/umap/spectral.py:324: RuntimeWarning: divide by zero encountered in divide
#   1.0 / np.sqrt(diag_data), 0, graph.shape[0], graph.shape[0]
# /stanley/WangLab/kamal/envs/xax/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %% [markdown]
# # Annotation

# %% [markdown]
# ## Load

# %%
sample_rate = 0.1
path = f'/stanley/WangLab/kamal/data/projects/spin/reviews/results/brain/utag/reconstructions_{sample_rate}_{radius}radius_{k_latent}latent/adata_{sample_rate}_umap.h5ad'
adata = sc.read_h5ad(path)

# %% [markdown]
# ## Assign labels

# %%
sc.set_figure_params(figsize=(5,5))
sc.pl.embedding(adata, basis='spatial', color='leiden', s=10)
# Out:
# /stanley/WangLab/kamal/envs/xax/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
sc.set_figure_params(figsize=(5,5))
sc.pl.embedding(adata, basis='spatial', color='leiden', s=10, groups='23')
# Out:
# /stanley/WangLab/kamal/envs/xax/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
leiden2region = {
    '0': 'TH',
    '1': 'HY',
    '2': 'L6',
    '3': 'fiber tract',
    '4': 'L2/3',
    '5': 'COA',
    '6': 'L5',
    '7': 'HPFmo/BLA',
    '8': 'L4',
    '9': 'CP',
    '10': 'meninges/L1',
    '11': 'DG',
    '12': 'RSP',
    '13': 'PIR',
    '14': 'CA1',
    '15': 'MEA',
    '16': 'RT',
    '17': 'L6b',
    '18': 'LHb',
    '19': 'CA2/3',
    '20': 'chpl',
    '21': 'MHb',
    '22': 'VL',
    '23': 'vasculature',
}
adata.obs['region'] = adata.obs['leiden'].map(leiden2region)

# %% [markdown]
# ## Recolor

# %% [markdown]
# ### Transfer colors from preprint

# %%
olddata = sc.read_h5ad('/stanley/WangLab/kamal/code/remote_notebooks/spatial_autocorrelation/adata_all_techniques.h5ad')
old_regions = olddata.obs['region_smooth_subsampled'].unique()
palette = sc.pl.palettes.default_102
old_cmap = {old_regions[i]:palette[i] for i in range(len(old_regions))}

# %%
old_regions = set(old_regions)
new_regions = set(adata.obs['region'].unique())
shared_regions = old_regions.intersection(new_regions)
all_regions = old_regions.union(new_regions)

new_cmap = dict()
for region in shared_regions:
    new_cmap[region] = old_cmap[region]

print(new_regions-shared_regions)
print(old_regions-shared_regions)
# Out:
# {'MEA', 'chpl', 'L6b', 'HPFmo/BLA', 'COA', 'vasculature'}
# {'chpl2', 'MEA/COA', 'BLA', 'HPFmo', 'chpl1'}

# %%
new_cmap['chpl'] = old_cmap['chpl1']
new_cmap['COA'] = old_cmap['MEA/COA']
new_cmap['HPFmo/BLA'] = old_cmap['BLA']
new_cmap['L6b'] = old_cmap['HPFmo']
new_cmap['MEA'] = old_cmap['chpl2']
new_cmap['vasculature'] = sc.pl.palettes.default_102[24]

# %%
sc.set_figure_params(figsize=(5,5))
sc.pl.embedding(adata, basis='spatial', color='region', palette=new_cmap, s=10)
# Out:
# /stanley/WangLab/kamal/envs/xax/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %% [markdown]
# ### Tissue

# %%
sc.set_figure_params(figsize=(5,5))
sc.pl.embedding(adata, basis='spatial', color='region', s=20, frameon=False, legend_loc=False, title='',
return_fig=True, palette=new_cmap)

filename = f'leiden_{sample_rate}.png'
filepath = os.path.join(figpath,filename)
plt.savefig(filepath, bbox_inches='tight', dpi=dpi)
# Out:
# /stanley/WangLab/kamal/envs/xax/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %% [markdown]
# ### UMAP

# %%
sc.set_figure_params(figsize=(5,5))
sc.pl.embedding(adata, basis='X_umap', color='region', s=20, frameon=False, legend_loc=False, title='',
return_fig=True, palette=new_cmap)

filename = f'umap_{sample_rate}.png'
filepath = os.path.join(figpath,filename)
plt.savefig(filepath, bbox_inches='tight', dpi=dpi)
# Out:
# /stanley/WangLab/kamal/envs/xax/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:392: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %% [markdown]
# ## Save

# %%
adata.write(path[:-5]+'_annotated.h5ad')
